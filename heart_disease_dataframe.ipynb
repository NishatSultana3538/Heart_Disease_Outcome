# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
heart_disease_data_sets = "Resources/heart_2020_cleaned.csv"


# Read the  Data and  store into a Pandas DataFrame
heart_disease_data_sets_df = pd.read_csv(heart_disease_data_sets)

heart_disease_data_sets_df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
heart_disease_data_sets_df.head(10)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
# 5          Yes  28.87     Yes              No     No             6.0
# 6           No  21.63      No              No     No            15.0
# 7           No  31.64     Yes              No     No             5.0
# 8           No  26.45      No              No     No             0.0
# 9           No  40.69      No              No     No             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0          30.0          No  Female        55-59  White
# 1           0.0          No  Female  80 or older  White
# ...

# %%
list(heart_disease_data_sets_df)
# Out:
# ['HeartDisease',
#  'BMI',
#  'Smoking',
#  'AlcoholDrinking',
#  'Stroke',
#  'PhysicalHealth',
#  'MentalHealth',
#  'DiffWalking',
#  'Sex',
#  'AgeCategory',
#  'Race',
#  'Diabetic',
#  'PhysicalActivity',
#  'GenHealth',
#  'SleepTime',
#  'Asthma',
#  'KidneyDisease',
#  'SkinCancer']

# %% [markdown]
# df.reset_index(inplace=True)
# df = df.rename(columns = {'index':'new column name'})
# import pandas as pd
#
# data = {'Product': ['Computer','Printer','Monitor','Desk','Phone'],
#           'Price': [1200,250,400,700,350]
#         }
#
# df = pd.DataFrame(data, columns = ['Product','Price'], index = ['Item_1','Item_2','Item_3','Item_4','Item_5'])
#
# print(df)

# %%
heart_disease_data_sets_df.reset_index(inplace=True) 
heart_disease_data_sets_df = heart_disease_data_sets_df.rename(columns = {'index':'Patient_ID'}) 
heart_disease_data_sets_df.head(10)
# Out:
#    Patient_ID HeartDisease    BMI Smoking AlcoholDrinking Stroke  \
# 0           0           No  16.60     Yes              No     No
# 1           1           No  20.34      No              No    Yes
# 2           2           No  26.58     Yes              No     No
# 3           3           No  24.21      No              No     No
# 4           4           No  23.71      No              No     No
# 5           5          Yes  28.87     Yes              No     No
# 6           6           No  21.63      No              No     No
# 7           7           No  31.64     Yes              No     No
# 8           8           No  26.45      No              No     No
# 9           9           No  40.69      No              No     No
#
#    PhysicalHealth  MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0             3.0          30.0          No  Female        55-59  White
# 1             0.0           0.0          No  Female  80 or older  White
# ...

# %% [markdown]
# heart_disease_data_sets_df.set_axis(['PatientID', 'HeartDisease',
#  'BMI',
#  'Smoking',
#  'AlcoholDrinking',
#  'Stroke',
#  'PhysicalHealth',
#  'MentalHealth',
#  'DiffWalking',
#  'Sex',
#  'AgeCategory',
#  'Race',
#  'Diabetic',
#  'PhysicalActivity',
#  'GenHealth',
#  'SleepTime',
#  'Asthma',
#  'KidneyDisease',
#  'SkinCancer'],axis=1,inplace=True)

# %%
#df1 = df[['a', 'b']]
heart_disease_demographic_data_df = heart_disease_data_sets_df[['Patient_ID', 'HeartDisease', 'Sex', 'AgeCategory', 'Race']]
heart_disease_demographic_data_df.head(10)
# Out:
#    Patient_ID HeartDisease     Sex  AgeCategory   Race
# 0           0           No  Female        55-59  White
# 1           1           No  Female  80 or older  White
# 2           2           No    Male        65-69  White
# 3           3           No  Female        75-79  White
# 4           4           No  Female        40-44  White
# 5           5          Yes  Female        75-79  Black
# 6           6           No  Female        70-74  White
# 7           7           No  Female  80 or older  White
# 8           8           No  Female  80 or older  White
# 9           9           No    Male        65-69  White

# %%
heart_disease_behavioural_health_data_df = heart_disease_data_sets_df[['Patient_ID', 'HeartDisease',
 'BMI',
 'Smoking',
 'AlcoholDrinking',
 'Stroke',
 'PhysicalHealth',
 'MentalHealth',
 'DiffWalking']]
heart_disease_behavioural_health_data_df.head(10)
# Out:
#    Patient_ID HeartDisease    BMI Smoking AlcoholDrinking Stroke  \
# 0           0           No  16.60     Yes              No     No
# 1           1           No  20.34      No              No    Yes
# 2           2           No  26.58     Yes              No     No
# 3           3           No  24.21      No              No     No
# 4           4           No  23.71      No              No     No
# 5           5          Yes  28.87     Yes              No     No
# 6           6           No  21.63      No              No     No
# 7           7           No  31.64     Yes              No     No
# 8           8           No  26.45      No              No     No
# 9           9           No  40.69      No              No     No
#
#    PhysicalHealth  MentalHealth DiffWalking
# 0             3.0          30.0          No
# 1             0.0           0.0          No
# 2            20.0          30.0          No
# 3             0.0           0.0          No
# ...

# %%
heart_disease_other_disease_correlation_data_df = heart_disease_data_sets_df[['Patient_ID','Diabetic',
 'PhysicalActivity',
 'GenHealth',
 'SleepTime',
 'Asthma',
 'KidneyDisease',
 'SkinCancer']]
heart_disease_other_disease_correlation_data_df.head(10)
# Out:
#    Patient_ID                 Diabetic PhysicalActivity  GenHealth  SleepTime  \
# 0           0                      Yes              Yes  Very good        5.0
# 1           1                       No              Yes  Very good        7.0
# 2           2                      Yes              Yes       Fair        8.0
# 3           3                       No               No       Good        6.0
# 4           4                       No              Yes  Very good        8.0
# 5           5                       No               No       Fair       12.0
# 6           6                       No              Yes       Fair        4.0
# 7           7                      Yes               No       Good        9.0
# 8           8  No, borderline diabetes               No       Fair        5.0
# 9           9                       No              Yes       Good       10.0
#
#   Asthma KidneyDisease SkinCancer
# 0    Yes            No        Yes
# 1     No            No         No
# ...

# %%
#df.to_csv("data2.csv", index = False)
#heart_disease_demographic_data_df.to_csv('Resources/demographic_data.csv', index = False)
heart_disease_behavioural_health_data_df.to_csv('Resources/behavioural_data.csv', index = False)
heart_disease_other_disease_correlation_data_df.to_csv('Resources/other_disease_correlation_data.csv', index = False)
